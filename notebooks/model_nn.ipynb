# %%
# %cd /home/dani/projects/neuroscience
# Out:
# /home/dani/projects/neuroscience

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt

# %%
data = []
for i in range(30):
    data.append(np.load(f"data_processed/adhd/timeseries_{i}.npy"))

# %%
data[0].shape
# Out:
# (176, 39)

# %%
class TimeSeriesDataset(Dataset):
    """Dataset class for time series data with residual learning."""
    
    def __init__(self, data):
        """
        Args:
            data: numpy array of shape (n_t, n_x) where n_t is time steps, n_x is features
        """
        self.data = torch.FloatTensor(data)
        
    def __len__(self):
        return len(self.data) - 1  # We need pairs (x_t, x_{t+1})
    
    def __getitem__(self, idx):
        x_t = self.data[idx]
        x_t_plus_1 = self.data[idx + 1]
        return x_t, x_t_plus_1
    
class ResidualNN(nn.Module):
    """1-layer neural network for residual learning: x_{t+1} = x_t + f_θ(x_t)"""
    
    def __init__(self, input_dim, hidden_dim=20, activation='relu'):
        super(ResidualNN, self).__init__()
            
        # Single layer network f_θ(x_t)
        self.f_theta = nn.Sequential(
            nn.Linear(input_dim, input_dim),
            #nn.Tanh(),
            #nn.Linear(hidden_dim, input_dim)  # Output same size as input for residual
        )
    
    def forward(self, x_t):
        # Residual connection: x_{t+1} = x_t + f_θ(x_t)
        residual = self.f_theta(x_t)
        x_t_plus_1 = x_t + residual
        return x_t_plus_1

# %%
class ResidualNNTrainer:
    """Trainer class for the residual neural network."""
    
    def __init__(self, model, device='cpu'):
        self.model = model.to(device)
        self.device = device
        self.train_losses = []
        self.val_losses = []
        
    def train(self, train_loader, val_loader=None, epochs=100, lr=0.001, 
              criterion=nn.MSELoss(), optimizer_class=optim.Adam):
        """
        Train the model.
        
        Args:
            train_loader: DataLoader for training data
            val_loader: DataLoader for validation data (optional)
            epochs: Number of training epochs
            lr: Learning rate
            criterion: Loss function
            optimizer_class: Optimizer class
        """
        optimizer = optimizer_class(self.model.parameters(), lr=lr)
        
        for epoch in range(epochs):
            # Training
            self.model.train()
            train_loss = 0.0
            
            for x_t, x_t_plus_1 in train_loader:
                x_t = x_t.to(self.device)
                x_t_plus_1 = x_t_plus_1.to(self.device)
                
                optimizer.zero_grad()
                pred_x_t_plus_1 = self.model(x_t)
                loss = criterion(pred_x_t_plus_1, x_t_plus_1)
                loss.backward()
                optimizer.step()
                
                train_loss += loss.item()
            
            avg_train_loss = train_loss / len(train_loader)
            self.train_losses.append(avg_train_loss)
            
            # Validation
            if val_loader is not None:
                self.model.eval()
                val_loss = 0.0
                
                with torch.no_grad():
                    for x_t, x_t_plus_1 in val_loader:
                        x_t = x_t.to(self.device)
                        x_t_plus_1 = x_t_plus_1.to(self.device)
                        
                        pred_x_t_plus_1 = self.model(x_t)
                        loss = criterion(pred_x_t_plus_1, x_t_plus_1)
                        val_loss += loss.item()
                
                avg_val_loss = val_loss / len(val_loader)
                self.val_losses.append(avg_val_loss)
                
                if (epoch + 1) % 10 == 0:
                    print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')
            else:
                if (epoch + 1) % 10 == 0:
                    print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {avg_train_loss:.4f}')
    
    def predict(self, x_t):
        """Predict next state given current state."""
        self.model.eval()
        with torch.no_grad():
            if isinstance(x_t, np.ndarray):
                x_t = torch.FloatTensor(x_t).to(self.device)
            return self.model(x_t)
    
    def multi_step_prediction(self, x_0, n_steps):
        """Generate multi-step predictions starting from x_0."""
        self.model.eval()
        predictions = [x_0]
        x_current = x_0.clone() if isinstance(x_0, torch.Tensor) else torch.FloatTensor(x_0)
        x_current = x_current.to(self.device)
        
        with torch.no_grad():
            for _ in range(n_steps):
                x_next = self.model(x_current.unsqueeze(0) if x_current.dim() == 1 else x_current)
                if x_next.dim() > 1:
                    x_next = x_next.squeeze(0)
                predictions.append(x_next.cpu())
                x_current = x_next
                
        return torch.stack(predictions)
    
    def plot_losses(self):
        """Plot training and validation losses."""
        plt.figure(figsize=(10, 6))
        plt.plot(self.train_losses, label='Training Loss')
        if self.val_losses:
            plt.plot(self.val_losses, label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.title('Training Progress')
        plt.legend()
        plt.grid(True)
        plt.show()

# %%
len(data)
# Out:
# 30

# %%
n_t, n_x = data[0].shape
train_data = data[0]
val_data = data[1]

# Create datasets and dataloaders
train_dataset = TimeSeriesDataset(train_data)
val_dataset = TimeSeriesDataset(val_data)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Initialize model and trainer
model = ResidualNN(input_dim=n_x, hidden_dim=4,)
device = 'cpu' #'cuda' if torch.cuda.is_available() else 'cpu'
trainer = ResidualNNTrainer(model, device=device)

# Train the model
print("Training started...")
trainer.train(train_loader, val_loader, epochs=1000, lr=1e-2)

# Plot training progress
trainer.plot_losses()

# Example prediction
x_test = torch.FloatTensor(val_data[0])
x_pred = trainer.predict(x_test)
print(f"Input: {x_test}")
print(f"Predicted next state: {x_pred}")
print(f"Actual next state: {val_data[1]}")

# Multi-step prediction
multi_pred = trainer.multi_step_prediction(x_test, n_steps=10)
print(f"Multi-step predictions shape: {multi_pred.shape}")
# Out:
# Training started...
# Epoch [10/1000], Train Loss: 0.6660, Val Loss: 0.9337
# Epoch [20/1000], Train Loss: 0.5873, Val Loss: 0.9665
# Epoch [30/1000], Train Loss: 0.5675, Val Loss: 1.0082
# Epoch [40/1000], Train Loss: 0.5612, Val Loss: 1.0406
# Epoch [50/1000], Train Loss: 0.5590, Val Loss: 1.0626
# Epoch [60/1000], Train Loss: 0.5603, Val Loss: 1.0756
# Epoch [70/1000], Train Loss: 0.5580, Val Loss: 1.0832
# Epoch [80/1000], Train Loss: 0.5575, Val Loss: 1.0833
# Epoch [90/1000], Train Loss: 0.5586, Val Loss: 1.0927
# Epoch [100/1000], Train Loss: 0.5676, Val Loss: 1.0880
# Epoch [110/1000], Train Loss: 0.5636, Val Loss: 1.0894
# Epoch [120/1000], Train Loss: 0.5587, Val Loss: 1.0956
# Epoch [130/1000], Train Loss: 0.5603, Val Loss: 1.1023
# Epoch [140/1000], Train Loss: 0.5541, Val Loss: 1.0953
# Epoch [150/1000], Train Loss: 0.5607, Val Loss: 1.0919
# Epoch [160/1000], Train Loss: 0.5652, Val Loss: 1.1014
# Epoch [170/1000], Train Loss: 0.5611, Val Loss: 1.0942
# Epoch [180/1000], Train Loss: 0.5770, Val Loss: 1.0988
# Epoch [190/1000], Train Loss: 0.5597, Val Loss: 1.0888
# Epoch [200/1000], Train Loss: 0.5590, Val Loss: 1.0898
# Epoch [210/1000], Train Loss: 0.5551, Val Loss: 1.0973
# Epoch [220/1000], Train Loss: 0.5605, Val Loss: 1.1011
# Epoch [230/1000], Train Loss: 0.5516, Val Loss: 1.0956
# Epoch [240/1000], Train Loss: 0.5630, Val Loss: 1.0889
# Epoch [250/1000], Train Loss: 0.5599, Val Loss: 1.0969
# Epoch [260/1000], Train Loss: 0.5660, Val Loss: 1.0902
# Epoch [270/1000], Train Loss: 0.5557, Val Loss: 1.0903
# Epoch [280/1000], Train Loss: 0.5600, Val Loss: 1.0962
# Epoch [290/1000], Train Loss: 0.5678, Val Loss: 1.0927
# Epoch [300/1000], Train Loss: 0.5589, Val Loss: 1.0936
# Epoch [310/1000], Train Loss: 0.5635, Val Loss: 1.0957
# Epoch [320/1000], Train Loss: 0.5646, Val Loss: 1.0977
# Epoch [330/1000], Train Loss: 0.5572, Val Loss: 1.0950
# Epoch [340/1000], Train Loss: 0.5596, Val Loss: 1.0952
# Epoch [350/1000], Train Loss: 0.5594, Val Loss: 1.0957
# Epoch [360/1000], Train Loss: 0.5622, Val Loss: 1.1037
# Epoch [370/1000], Train Loss: 0.5697, Val Loss: 1.0974
# Epoch [380/1000], Train Loss: 0.5575, Val Loss: 1.1011
# Epoch [390/1000], Train Loss: 0.5672, Val Loss: 1.0961
# Epoch [400/1000], Train Loss: 0.5638, Val Loss: 1.0900
# Epoch [410/1000], Train Loss: 0.5770, Val Loss: 1.0945
# Epoch [420/1000], Train Loss: 0.5541, Val Loss: 1.0996
# Epoch [430/1000], Train Loss: 0.5657, Val Loss: 1.0985
# Epoch [440/1000], Train Loss: 0.5647, Val Loss: 1.1000
# Epoch [450/1000], Train Loss: 0.5609, Val Loss: 1.0904
# Epoch [460/1000], Train Loss: 0.5656, Val Loss: 1.0952
# Epoch [470/1000], Train Loss: 0.5666, Val Loss: 1.0923
# Epoch [480/1000], Train Loss: 0.5576, Val Loss: 1.0997
# Epoch [490/1000], Train Loss: 0.5573, Val Loss: 1.0968
# Epoch [500/1000], Train Loss: 0.5635, Val Loss: 1.0971
# Epoch [510/1000], Train Loss: 0.5588, Val Loss: 1.0986
# Epoch [520/1000], Train Loss: 0.5554, Val Loss: 1.0939
# Epoch [530/1000], Train Loss: 0.5613, Val Loss: 1.0906
# Epoch [540/1000], Train Loss: 0.5570, Val Loss: 1.0955
# Epoch [550/1000], Train Loss: 0.5539, Val Loss: 1.0922
# Epoch [560/1000], Train Loss: 0.5655, Val Loss: 1.0935
# Epoch [570/1000], Train Loss: 0.5650, Val Loss: 1.0955
# Epoch [580/1000], Train Loss: 0.5590, Val Loss: 1.0965
# Epoch [590/1000], Train Loss: 0.5611, Val Loss: 1.0963
# Epoch [600/1000], Train Loss: 0.5584, Val Loss: 1.0963
# Epoch [610/1000], Train Loss: 0.5562, Val Loss: 1.0961
# Epoch [620/1000], Train Loss: 0.5599, Val Loss: 1.1020
# Epoch [630/1000], Train Loss: 0.5558, Val Loss: 1.0895
# Epoch [640/1000], Train Loss: 0.5582, Val Loss: 1.0986
# Epoch [650/1000], Train Loss: 0.5561, Val Loss: 1.0959
# Epoch [660/1000], Train Loss: 0.5618, Val Loss: 1.0931
# Epoch [670/1000], Train Loss: 0.5621, Val Loss: 1.0962
# Epoch [680/1000], Train Loss: 0.5668, Val Loss: 1.1019
# Epoch [690/1000], Train Loss: 0.5626, Val Loss: 1.1034
# Epoch [700/1000], Train Loss: 0.5631, Val Loss: 1.0943
# Epoch [710/1000], Train Loss: 0.5536, Val Loss: 1.0987
# Epoch [720/1000], Train Loss: 0.5598, Val Loss: 1.0969
# Epoch [730/1000], Train Loss: 0.5625, Val Loss: 1.0937
# Epoch [740/1000], Train Loss: 0.5578, Val Loss: 1.1014
# Epoch [750/1000], Train Loss: 0.5634, Val Loss: 1.1063
# Epoch [760/1000], Train Loss: 0.5586, Val Loss: 1.0900
# Epoch [770/1000], Train Loss: 0.5614, Val Loss: 1.0877
# Epoch [780/1000], Train Loss: 0.5619, Val Loss: 1.0911
# Epoch [790/1000], Train Loss: 0.5603, Val Loss: 1.0957
# Epoch [800/1000], Train Loss: 0.5647, Val Loss: 1.0995
# Epoch [810/1000], Train Loss: 0.5574, Val Loss: 1.0946
# Epoch [820/1000], Train Loss: 0.5550, Val Loss: 1.0962
# Epoch [830/1000], Train Loss: 0.5636, Val Loss: 1.0976
# Epoch [840/1000], Train Loss: 0.5605, Val Loss: 1.1019
# Epoch [850/1000], Train Loss: 0.5753, Val Loss: 1.0902
# Epoch [860/1000], Train Loss: 0.5666, Val Loss: 1.0980
# Epoch [870/1000], Train Loss: 0.5646, Val Loss: 1.1022
# Epoch [880/1000], Train Loss: 0.5665, Val Loss: 1.0969
# Epoch [890/1000], Train Loss: 0.5642, Val Loss: 1.0960
# Epoch [900/1000], Train Loss: 0.5605, Val Loss: 1.0917
# Epoch [910/1000], Train Loss: 0.5648, Val Loss: 1.0924
# Epoch [920/1000], Train Loss: 0.5675, Val Loss: 1.0857
# Epoch [930/1000], Train Loss: 0.5540, Val Loss: 1.0944
# Epoch [940/1000], Train Loss: 0.5679, Val Loss: 1.0928
# Epoch [950/1000], Train Loss: 0.5715, Val Loss: 1.0957
# Epoch [960/1000], Train Loss: 0.5533, Val Loss: 1.0889
# Epoch [970/1000], Train Loss: 0.5541, Val Loss: 1.1038
# Epoch [980/1000], Train Loss: 0.5624, Val Loss: 1.0995
# Epoch [990/1000], Train Loss: 0.5680, Val Loss: 1.1095
# Epoch [1000/1000], Train Loss: 0.5544, Val Loss: 1.1036
# Input: tensor([-1.1503, -0.8954, -0.4659, -0.1060,  0.8791,  0.4317,  0.4063, -1.8700,
#         -0.3873,  0.6163, -0.8509, -0.4326,  0.5201, -0.5282,  0.5184,  0.5902,
#         -0.1812,  0.6599,  0.1574, -0.0608, -0.8304,  0.3473, -0.8482, -0.3483,
#         -0.7224, -0.9604, -1.2767,  0.4173,  0.6400,  0.0773,  0.8926,  0.0384,
#          0.0132,  0.1455, -0.8967, -0.5891, -0.0742,  0.2572,  0.2078])
# Predicted next state: tensor([-0.4634, -0.3376,  0.0060, -0.1885,  0.4948, -0.2724,  0.6817, -0.3131,
#         -0.5907,  0.8306,  0.5762,  0.5055,  0.2175, -0.1348,  0.8471,  0.8493,
#          0.1349,  0.2106,  0.2047, -0.1717, -0.4793, -0.4272, -0.6580, -0.4503,
#         -0.0754, -0.4690, -0.8258,  0.1681,  0.2070, -0.1987, -0.1495,  0.5330,
#         -0.2742, -0.1703,  0.0522, -0.4453,  0.0798, -0.1550, -0.0873])
# Actual next state: [ 0.68328811 -0.1766352  -0.02726714 -0.24694209  0.12736072  1.93091851
#  -0.16243388 -2.73744257 -0.02945325 -0.68855334 -1.64578191 -1.01843422
#   0.936991   -1.04743874 -0.87928383 -0.19159444 -1.08572307 -0.56787727
#  -0.62713751 -1.48114547 -2.17139952 -0.18718336 -0.16348896  0.2409814
#   0.20315631  0.44765141 -0.59478348  1.25315758  1.08220381  1.31106931
#   1.32921626  1.37446984 -1.01389944 -0.15502277 -0.87670526  0.14803272
#   0.14754832  0.12701743  0.62568352]
# Multi-step predictions shape: torch.Size([11, 39])
